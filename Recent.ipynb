# %%
# Core LangChain components
# !pip install langchain langchain-community faiss-cpu openai tiktoken pandas

# Vector store
# !pip install faiss-cpu

# Embeddings + LLM
# !pip install openai tiktoken

# Data handling
# !pip install pandas
# Out:
# Requirement already satisfied: langchain in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (1.2.7)
# Requirement already satisfied: langchain-community in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (0.4.1)
# Requirement already satisfied: faiss-cpu in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (1.13.2)
# Requirement already satisfied: openai in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (2.15.0)
# Requirement already satisfied: tiktoken in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (0.12.0)
# Requirement already satisfied: pandas in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (3.0.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.7 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from langchain) (1.2.7)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.7 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from langchain) (1.0.7)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from langchain) (2.10.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (0.6.4)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (9.0.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (4.12.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.7->langchain) (2.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from langgraph<1.1.0,>=1.0.7->langchain) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.7 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from langgraph<1.1.0,>=1.0.7->langchain) (1.0.7)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from langgraph<1.1.0,>=1.0.7->langchain) (0.3.3)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from langgraph<1.1.0,>=1.0.7->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.7->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (0.23.0)
# Requirement already satisfied: anyio in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (4.7.0)
# Requirement already satisfied: certifi in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (1.0.9)
# Requirement already satisfied: idna in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (3.7)
# Requirement already satisfied: h11>=0.16 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from langchain-community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from langchain-community) (2.0.39)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from langchain-community) (3.11.10)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from langchain-community) (2.1.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.18.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.1.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (2.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.0.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from openai) (0.12.0)
# Requirement already satisfied: sniffio in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from openai) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: faiss-cpu in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (1.13.2)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from faiss-cpu) (2.1.3)
# Requirement already satisfied: packaging in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from faiss-cpu) (24.2)
# Requirement already satisfied: openai in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (2.15.0)
# Requirement already satisfied: tiktoken in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (0.12.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from openai) (4.7.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from openai) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from openai) (2.10.5)
# Requirement already satisfied: sniffio in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: certifi in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (2.27.2)
# Requirement already satisfied: regex>=2022.1.18 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from tiktoken) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from requests>=2.26.0->tiktoken) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from requests>=2.26.0->tiktoken) (2.3.0)
# Requirement already satisfied: pandas in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (3.0.0)
# Requirement already satisfied: numpy>=1.26.0 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/U467776/opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
from langchain_core.documents import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain.llms import OpenAI
from langchain.chains import RetrievalQA
# Out:
# /Users/U467776/opt/anaconda3/lib/python3.13/site-packages/pandas/core/computation/expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
import os

# Set your OpenAI API key as an environment variable
os.environ["OPENAI_API_KEY"] = "YOUR_API_KEY_HERE"

# %%
# Load email thread data
emails_df = pd.read_csv("emails.csv")

# Load thread summaries
summaries_df = pd.read_csv("summaries.csv")

# Merge both files using thread_id
merged_df = pd.merge(emails_df, summaries_df, on="thread_id", how="left")

# %%
documents = []

for _, row in merged_df.iterrows():
    # Combine all relevant information into a single text block
    content = f"""
    Thread ID: {row['thread_id']}
    Subject: {row['subject']}
    From: {row['from']}
    To: {row['to']}
    Timestamp: {row['timestamp']}
    Summary: {row.get('summary', '')}
    
    Email Body:
    {row['body']}
    """

    # Create a LangChain Document with metadata
    doc = Document(
        page_content=content,
        metadata={
            "thread_id": row["thread_id"],
            "subject": row["subject"],
            "from": row["from"],
            "timestamp": row["timestamp"]
        }
    )

    documents.append(doc)

# %%
# Split documents into smaller chunks for better embedding quality
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=800,
    chunk_overlap=100
)

split_docs = text_splitter.split_documents(documents)

# %%
# Initialize embedding model
embeddings = OpenAIEmbeddings()

# Create FAISS vector store from document chunks
vectorstore = FAISS.from_documents(split_docs, embeddings)

# %%
# Retriever fetches the most relevant chunks for a query
retriever = vectorstore.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 4}
)

# %%
# Initialize the LLM
llm = OpenAI(temperature=0)

# Create RetrievalQA chain
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",   # Simple and effective for document QA
    retriever=retriever,
    return_source_documents=True
)

# %%
# User query
query = "What decisions were made regarding budget approval?"

# Run query through the RAG pipeline
result = qa_chain(query)

# Print the generated answer
print("Answer:")
print(result["result"])

# %%
print("\nSources:\n")

for doc in result["source_documents"]:
    print(f"Thread ID: {doc.metadata['thread_id']}")
    print(f"Subject: {doc.metadata['subject']}")
    print(f"From: {doc.metadata['from']}")
    print(f"Timestamp: {doc.metadata['timestamp']}")
    print("-" * 50)
